# %% [markdown]
# Intrucciones:
# Desarrollar el código en un notebook de Google Colab y después subirlo a su repositorio de GitHub en una carpeta con el nombre.
# "El usuario dará un número al azar y el código calculará la suma de todos los números desde el 1 hasta el número dado por el usuario.
# Ejemplo: el usuario dió el número 5, el código deberá de dar como resultado 15."

# %% [markdown]
# Nombre: Ana Paula Cantú Díaz
# Matricula: 1663389
# Clase: sabados N1
# INTELIGENCIA ARTIFICIAL Y REDES NEURONALES

# %%
numero_inicial = int(input("Ingresa un número: "))
sumatoria = 0
for numero in range(numero_inicial):
    sumatoria = sumatoria + (numero + 1)

print("La sumatoria de los numeros es: ",sumatoria)
# Out:
# Ingresa un número: 45
# La sumatoria de los numeros es:  1035
